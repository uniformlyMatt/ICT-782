# %%
import pandas as pd
import numpy as np

# %%
a2 = pd.read_json('A2data.json')
a2
# Out:
#        id         emp      ic  hh
# 0    1000   part-time  118000   4
# 1    1001   full-time   42000   2
# 2    1002   full-time  105000  10
# 3    1003  unemployed   65000   6
# 4    1004   full-time  190000   5
# ..    ...         ...     ...  ..
# 995  1995   full-time  167000   7
# 996  1996   full-time   89000   7
# 997  1997  unemployed   74000  11
# 998  1998  unemployed  223000   3
# 999  1999   part-time  180000   4
#
# [1000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

a2['hh'].replace(999, np.nan, inplace = True)

ax.scatter(a2['hh'], a2['ic'], color = 'b');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7bb4cdcc82c> in <module>
#       3 fig, ax = plt.subplots()
#       4
# ----> 5 a2['hh'].replace(999, np.nan, inplace = True)
#       6
#       7 ax.scatter(a2['hh'], a2['ic'], color = 'b');
#
# NameError: name 'a2' is not defined

# %%
data = pd.read_csv('d1.csv')
data
# Out:
#    REF_DATE     GEO           DGUID                             Products  \
# 0   2019-08  Canada  2016A000011124    Crude oil and equivalent products
# 1   2019-09  Canada  2016A000011124    Crude oil and equivalent products
# 2   2019-10  Canada  2016A000011124    Crude oil and equivalent products
# 3   2019-11  Canada  2016A000011124    Crude oil and equivalent products
# 4   2019-12  Canada  2016A000011124    Crude oil and equivalent products
# ..      ...     ...             ...                                  ...
# 75  2019-08  Canada  2016A000011124  Propane, butane, and other products
# 76  2019-09  Canada  2016A000011124  Propane, butane, and other products
# 77  2019-10  Canada  2016A000011124  Propane, butane, and other products
# 78  2019-11  Canada  2016A000011124  Propane, butane, and other products
# 79  2019-12  Canada  2016A000011124  Propane, butane, and other products
#
#              Pipeline    Statistics           UOM  UOM_ID SCALAR_FACTOR  \
# ...

# %%
ax.plot(data.loc[['Crude oil','Imports']])
