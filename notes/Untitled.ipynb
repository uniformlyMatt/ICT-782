# %%
import pandas as pd
import numpy as np

data = pd.read_csv('data1.csv')
data
# Out:
#     Unnamed: 0  TIME                                        GEO        UNIT  \
# 0            0  2005  European Union - 27 countries (from 2020)  Percentage
# 1            1  2005  European Union - 28 countries (2013-2020)  Percentage
# 2            2  2005                                    Belgium  Percentage
# 3            3  2005                                   Bulgaria  Percentage
# 4            4  2005                                    Czechia  Percentage
# ..         ...   ...                                        ...         ...
# 85          85  2015                                   Slovenia  Percentage
# 86          86  2015                                   Slovakia  Percentage
# 87          87  2015                                    Finland  Percentage
# 88          88  2015                                     Sweden  Percentage
# 89          89  2015                             United Kingdom  Percentage
#
# ...

# %%
data.drop(range(0,90,2), axis = 0, inplace = True)

# %%
data
# Out:
#     Unnamed: 0  TIME                                        GEO        UNIT  \
# 1            1  2005  European Union - 28 countries (2013-2020)  Percentage
# 3            3  2005                                   Bulgaria  Percentage
# 5            5  2005                                    Denmark  Percentage
# 7            7  2005                                    Estonia  Percentage
# 9            9  2005                                     Greece  Percentage
# 11          11  2005                                     France  Percentage
# 13          13  2005                                      Italy  Percentage
# 15          15  2005                                     Latvia  Percentage
# 17          17  2005                                 Luxembourg  Percentage
# 19          19  2005                                      Malta  Percentage
# 21          21  2005                                    Austria  Percentage
# ...

# %%
rows = [i for i in range(0,90,2)]

data.drop(rows, axis = 0, inplace = True)
data
# Out:
#     Unnamed: 0  TIME                                        GEO        UNIT  \
# 1            1  2005  European Union - 28 countries (2013-2020)  Percentage
# 3            3  2005                                   Bulgaria  Percentage
# 5            5  2005                                    Denmark  Percentage
# 7            7  2005                                    Estonia  Percentage
# 9            9  2005                                     Greece  Percentage
# 11          11  2005                                     France  Percentage
# 13          13  2005                                      Italy  Percentage
# 15          15  2005                                     Latvia  Percentage
# 17          17  2005                                 Luxembourg  Percentage
# 19          19  2005                                      Malta  Percentage
# 21          21  2005                                    Austria  Percentage
# ...

# %%
data.index[1::2]
# Out:
# Int64Index([ 3,  7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67,
#             71, 75, 79, 83, 87],
#            dtype='int64')

# %%
data
# Out:
#     Unnamed: 0  TIME                                        GEO        UNIT  \
# 1            1  2005  European Union - 28 countries (2013-2020)  Percentage
# 3            3  2005                                   Bulgaria  Percentage
# 5            5  2005                                    Denmark  Percentage
# 7            7  2005                                    Estonia  Percentage
# 9            9  2005                                     Greece  Percentage
# 11          11  2005                                     France  Percentage
# 13          13  2005                                      Italy  Percentage
# 15          15  2005                                     Latvia  Percentage
# 17          17  2005                                 Luxembourg  Percentage
# 19          19  2005                                      Malta  Percentage
# 21          21  2005                                    Austria  Percentage
# ...
